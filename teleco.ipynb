# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# Find out how many female senior citizens there in the dataset 
  
  
df[df['Churn']=='Yes']
sns.countplot(x=df['Churn'],hue=df['gender'])
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='count'>

# %%
###those who churned is equal for men and women gender
###those who didnt churned male gender is higher than female gender

# %%
#Find out how many female senior citizens there in the dataset
Sc=df[(df['SeniorCitizen']==1) & (df['gender']=='Female')]
Sc['SeniorCitizen'].value_counts()
# Out:
# 1    568
# Name: SeniorCitizen, dtype: int64

# %%
# Compare 'tenure' with 'Total Charges' 
sns.scatterplot(x=df['tenure'],y=df['TotalCharges'],data=df)
plt.title('Comparison of Tenure with Total Charges')
plt.show()

# %%
###as tenure increases total charges increases
#Find out which contract is preffered by the senior citizen.
sns.countplot(x=df[df['SeniorCitizen']==1]['Contract'])
plt.show()

# %%
###senior citizens prefer month to month contract
 #our findings on Payment Method
sns.countplot(x=df['PaymentMethod'],data=df)
plt.xticks(rotation=90);
plt.show()

# %%
###we find that most of them prefer electronic payment
